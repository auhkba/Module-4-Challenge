# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csv_whale = Path('Resources/whale_returns.csv')
df_whale = pd.read_csv(csv_whale,parse_dates=True, index_col="Date", infer_datetime_format=True)
df_whale.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
df_whale.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
df_whale=df_whale.dropna()
df_whale.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
df_whale.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
csv_algo = Path('Resources/algo_returns.csv')
df_algo = pd.read_csv(csv_algo,parse_dates=True, index_col="Date", infer_datetime_format=True)
df_algo.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
df_algo.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
df_algo = df_algo.dropna()
df_algo.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
df_algo.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csv_sp500 = Path('Resources/sp500_history.csv')
df_sp500 = pd.read_csv(csv_sp500,parse_dates=True, index_col="Date", infer_datetime_format=True)
df_sp500.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
df_sp500.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
df_sp500['Close'] = df_sp500['Close'].str.replace('$','')
df_sp500['Close'] = df_sp500['Close'].astype(float)
df_sp500['Close'].dtype
# Out:
# C:\Users\matth\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# dtype('float64')

# %%
# Calculate Daily Returns
df_sp500 = df_sp500.pct_change()
df_sp500.sample(5)
# Out:
#                Close
# Date
# 2016-04-19 -0.000761
# 2017-08-23  0.002079
# 2018-06-18  0.004040
# 2017-09-13  0.001102
# 2014-12-23  0.000139

# %%
# Drop nulls
df_sp500 = df_sp500.dropna()
df_sp500.head()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
# Rename `Close` Column to be specific to this portfolio.
df_sp500 = df_sp500.rename(columns={'Close': 'SP500'})
df_sp500.head()
# Out:
#                SP500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
all_return = pd.concat([df_whale,df_algo,df_sp500], axis='columns', join='inner')
all_return.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
port_return = all_return.drop(columns=['SP500'])
port_return.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
port_return_compound = (1 + port_return).cumprod() - 1

# Plot cumulative returns
port_return_compound.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
port_return.plot(kind='box',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
port_return_std = port_return.std()
port_return_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
df_sp500_std = df_sp500.std()
print(df_sp500_std)
# Determine which portfolios are riskier than the S&P 500
port_return_std = port_return_std.sort_values(ascending=False)
port_return_std
# Out:
# SP500    0.008135
# dtype: float64
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# Algo 2                         0.008341
# SOROS FUND MANAGEMENT LLC      0.007896
# Algo 1                         0.007623
# PAULSON & CO.INC.              0.007026
# dtype: float64

# %% [markdown]
# #### <Berkshire , Tiger Global and Aglo 2 have higher std than SP500, therefore they are riskier than SP500>

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std_port = port_return_std * np.sqrt(252)
annualized_std_port
# Out:
# BERKSHIRE HATHAWAY INC         0.205079
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# Algo 2                         0.132413
# SOROS FUND MANAGEMENT LLC      0.125348
# Algo 1                         0.121006
# PAULSON & CO.INC.              0.111527
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
port_return_std21 = port_return.rolling(window=21).std()
# Plot the rolling standard deviation
port_return_std21.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
port_return_corr = port_return.corr()
# Display de correlation matrix
port_return_corr
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# Algo 2                                          0.507160
#
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
soros_covariance = all_return['SOROS FUND MANAGEMENT LLC'].cov(all_return['SP500'])
paulson_covariance = all_return['PAULSON & CO.INC. '].cov(all_return['SP500'])
tiger_covariance = all_return['TIGER GLOBAL MANAGEMENT LLC'].cov(all_return['SP500'])
berk_covariance = all_return['BERKSHIRE HATHAWAY INC'].cov(all_return['SP500'])
algo1_covariance = all_return['Algo 1'].cov(all_return['SP500'])
algo2_covariance = all_return['Algo 2'].cov(all_return['SP500'])

# Calculate variance of S&P 500
var_sp500 = all_return['SP500'].var()

# Computing beta
soros_beta = round(soros_covariance/var_sp500,4)
paulson_beta = round(paulson_covariance/var_sp500,4)
tiger_beta = round(tiger_covariance/var_sp500,4)
berk_beta = round(berk_covariance/var_sp500,4)
algo1_beta = round(algo1_covariance/var_sp500,4)
algo2_beta = round(algo2_covariance/var_sp500,4)
print(f'Betas:\nSoros:{soros_beta} | Paulson:{paulson_beta} | Tiger:{tiger_beta} | Berkshire:{berk_beta} | Algo 1:{algo1_beta} | Algo 2:{algo2_beta}')

# Plot beta trend
rolling_covariance = all_return['SOROS FUND MANAGEMENT LLC'].rolling(window=60).cov(all_return['SP500'])
rolling_variance = all_return['SP500'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of SOROS FUND')
# Out:
# Betas:
# Soros:0.0005 | Paulson:0.0111 | Tiger:-0.0019 | Berkshire:-0.0208 | Algo 1:-0.0301 | Algo 2:-0.0021
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of SOROS FUND'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
soros_ewm = all_return['SOROS FUND MANAGEMENT LLC'].ewm(span=21).std()
soros_ewm
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04    0.002472
# 2015-03-05    0.002658
# 2015-03-06    0.005515
# 2015-03-09    0.004716
#                 ...
# 2019-04-15    0.005817
# 2019-04-16    0.005551
# 2019-04-17    0.005487
# 2019-04-18    0.005232
# 2019-04-22    0.005136
# Name: SOROS FUND MANAGEMENT LLC, Length: 1042, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (port_return.mean() * 252) / (port_return_std * np.sqrt(252))
sharpe_ratios
# Out:
# Algo 1                         1.369589
# Algo 2                         0.484334
# BERKSHIRE HATHAWAY INC         0.606743
# PAULSON & CO.INC.             -0.491422
# SOROS FUND MANAGEMENT LLC      0.342894
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar(title='Sharpe Ratios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %%
sharp_sp500 = (df_sp500.mean()*252)/(df_sp500_std*np.sqrt(252))
sharp_sp500
# Out:
# SP500   -0.774405
# dtype: float64

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!
# * Algo 1 outperforms both S&P500 and whales portfolios because it has substaintilly higher Sharp Ratios and lower standard deviation than others.
# * Algo 2 generally performs similar as whales porfolios, but still outperforms S&P500.
# * Aglo 1 presents relativly low correlation to all others, which offer other porfolios a good addition/or replacemnet of their stocks to improve their performance.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
csv_aapl = Path('Resources/aapl_historical.csv')
df_aapl = pd.read_csv(csv_aapl,parse_dates=True, index_col="Trade DATE", infer_datetime_format=True)
df_aapl.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Reading data from 2nd stock
csv_cost = Path('Resources/cost_historical.csv')
df_cost = pd.read_csv(csv_cost,parse_dates=True, index_col="Trade DATE", infer_datetime_format=True)
df_cost.tail()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-17   COST  199.60
# 2018-05-16   COST  198.71
# 2018-05-15   COST  195.48
# 2018-05-14   COST  195.88
# 2018-05-11   COST  195.76

# %%
# Reading data from 3rd stock
csv_goog = Path('Resources/goog_historical.csv')
df_goog = pd.read_csv(csv_goog,parse_dates=True, index_col="Trade DATE", infer_datetime_format=True)
df_goog.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Combine all stocks in a single DataFrame
df_aapl = df_aapl.rename(columns={'NOCP': 'AAPL'})
df_cost = df_cost.rename(columns={'NOCP': 'COST'})
df_goog = df_goog.rename(columns={'NOCP': 'GOOG'})
df_combined = pd.concat([df_aapl,df_cost,df_goog],axis='columns', join='inner')
df_combined.head()
# Out:
#            Symbol    AAPL Symbol    COST Symbol     GOOG
# Trade DATE
# 2019-05-09   AAPL  200.72   COST  243.47   GOOG  1162.38
# 2019-05-08   AAPL  202.90   COST  241.34   GOOG  1166.27
# 2019-05-07   AAPL  202.86   COST  240.18   GOOG  1174.10
# 2019-05-06   AAPL  208.48   COST  244.23   GOOG  1189.39
# 2019-05-03   AAPL  211.75   COST  244.62   GOOG  1185.40

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol
df_combined = df_combined.drop(columns='Symbol')
df_combined.head()
# Out:
#               AAPL    COST     GOOG
# Trade DATE
# 2019-05-09  200.72  243.47  1162.38
# 2019-05-08  202.90  241.34  1166.27
# 2019-05-07  202.86  240.18  1174.10
# 2019-05-06  208.48  244.23  1189.39
# 2019-05-03  211.75  244.62  1185.40

# %%
# Calculate daily returns
df_combined_daily = df_combined.pct_change()
# Drop NAs
my_port = df_combined_daily.dropna()
# Display sample data
my_port.sample(5)
# Out:
#                 AAPL      COST      GOOG
# Trade DATE
# 2018-10-01 -0.008810 -0.007193 -0.004000
# 2019-04-05 -0.015492 -0.002637  0.002750
# 2018-05-29  0.002133 -0.014526 -0.007005
# 2018-07-30 -0.001997  0.001829  0.002037
# 2018-06-06  0.002688 -0.024239  0.011585

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
my_return = my_port.dot(weights)

# Display sample data
my_return.sample(5)
# Out:
# Trade DATE
# 2018-06-14   -0.000118
# 2019-04-09   -0.004172
# 2018-08-24   -0.006594
# 2019-01-18    0.018159
# 2019-02-01   -0.017132
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
new_port = pd.concat([port_return,my_return,df_sp500],axis='columns', join='inner')
new_port.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
#
#               Algo 2         0     SP500
# 2018-05-11  0.000281 -0.000012 -0.000883
# 2018-05-14  0.001635  0.010216  0.006889
# 2018-05-15 -0.001139 -0.009283 -0.004044
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
new_port = new_port.rename(columns={0: 'My'})
new_port = new_port.dropna()
new_port.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# My                             0
# SP500                          0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
new_port_std = new_port.std()
annualized_std_new_port = new_port_std * np.sqrt(252)
annualized_std_new_port
# Out:
# SOROS FUND MANAGEMENT LLC      0.146589
# PAULSON & CO.INC.              0.116683
# TIGER GLOBAL MANAGEMENT LLC    0.232434
# BERKSHIRE HATHAWAY INC         0.246819
# Algo 1                         0.133645
# Algo 2                         0.139204
# My                             0.213137
# SP500                          0.152147
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
new_port_std21 = new_port.rolling(window=21).std()
# Plot rolling standard deviation
new_port_std21.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
new_port_corr = new_port.corr()
new_port_corr
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.791031
# PAULSON & CO.INC.                             0.791031            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.476938            0.484917
# BERKSHIRE HATHAWAY INC                        0.816190            0.650132
# Algo 1                                        0.336890            0.360668
# Algo 2                                        0.861989            0.783856
# My                                            0.061503            0.025680
# SP500                                        -0.028091           -0.059893
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.476938
# PAULSON & CO.INC.                               0.484917
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.323931
# ...

# %%
import seaborn as sns

sns.heatmap(new_port_corr, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
my_covariance = new_port['My'].cov(new_port['SP500'])
my_beta = my_covariance/new_port['SP500'].var()
my_rolling_covariance = new_port['My'].rolling(window=60).cov(new_port['SP500'])
my_rolling_variance = new_port['SP500'].rolling(window=60).var()
my_rolling_beta = my_rolling_covariance / my_rolling_variance
my_rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of MY FUND')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of MY FUND'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
new_sharpe_ratios = (new_port.mean() * 252) / (new_port_std * np.sqrt(252))
new_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.344766
# PAULSON & CO.INC.              0.236041
# TIGER GLOBAL MANAGEMENT LLC   -1.052249
# BERKSHIRE HATHAWAY INC         0.085005
# Algo 1                         1.999866
# Algo 2                         0.009467
# My                            -0.613547
# SP500                         -0.432942
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
new_sharpe_ratios.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# * my porfolio's correlation with SP500 is 0.87, which is highly correlated to SP500.
# * The risk (measured by Standard Deviation (0.21)) is high compared to Aglo 1(0.13) and 2(0.14).
# * Rolling Beta is consistanly between 1 - 1.3, my porfolio is performing better than SP500 if bull market is present.
# * My Sharp Ratio is also low (-0.61), my porfolio offers low risk/return matric compared with others.
